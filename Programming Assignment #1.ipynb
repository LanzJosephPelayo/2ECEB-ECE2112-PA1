# %% [markdown]
# # ECE2112 PROGRAMMING ASSIGNMENT #1

# %% [markdown]
# # BY: LANZ JOSEPH S. PELAYO || 2ECE-B || SUBMITTED AND PRODUCED ON AUGUST 27, 2026.

# %% [markdown]
# # A. WORD ROTATION PROBLEM

# %% [markdown]
# Code:

# %%
def rotate_word(text):
    out = text[1:] + text[0]
    return out

# %% [markdown]
# Output Tests:

# %%
print(rotate_word("python"))
print(rotate_word("logic"))
print(rotate_word("Code") )
print(rotate_word("A"))
# Out:
# ythonp
# ogicl
# odeC
# A

# %% [markdown]
# # B. USERNAME BUILDER PROBLEM

# %% [raw]
# Code:

# %%
def make_username(first, last):
    first = first.lower()
    last = last.lower()
    first = first.replace(" ", "")
    last = last.replace(" ", "")
    out = first + "." + last
    return out

# %% [markdown]
# Output Tests:

# %%
print(make_username("Ada", "Lovelace"))
print(make_username("Alan", "Turing"))
print(make_username("Ana Maria", "De Leon"))
print(make_username("JUDE", "BellingHam"))
print(make_username("Harry", "Kane"))
# Out:
# ada.lovelace
# alan.turing
# anamaria.deleon
# jude.bellingham
# harry.kane

# %% [markdown]
# # C. BOOKEND SWAP PROBLEM

# %% [markdown]
# Code:

# %%
def swap_bookends(items):
    first, *middle, last = items
    return [last] + middle + [first]

# %% [markdown]
# Output Tests:

# %%
print(swap_bookends([1, 2, 3, 4, 5, 6]))
print(swap_bookends(["red", "green", "blue"]))
print(swap_bookends([8, 3]))
print(swap_bookends(["Spain", "Argentina", "France", "England"]))
# Out:
# [6, 2, 3, 4, 5, 1]
# ['blue', 'green', 'red']
# [3, 8]
# ['England', 'Argentina', 'France', 'Spain']
